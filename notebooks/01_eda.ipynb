# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
df = pd.read_csv("../data/raw/telco_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
df.info()
# Out:
# Dataset Shape: (7043, 21)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df["Churn_binary"] = df["Churn"].map({"Yes": 1, "No": 0})

# %% [markdown]
# This shows a class imbalance with approximately 73% non-churned Customers and 26% churned customers. Instead we should use recall,F1-score and ROC-AUC instead of accuracy to evaluate models

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

print("Categorical Columns:", categorical_cols.tolist())
print("Numerical Columns:", numerical_cols.tolist())
# Out:
# Categorical Columns: ['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']
# Numerical Columns: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn_binary']

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# Churn_binary         0
# dtype: int64

# %% [markdown]
# After converting Total Charges from an object to numeric, we can see that there are 11 missing values. These correspond to customers with zero tenure, for whom total charges are not yet accured. We will impute 0 into these to preserve data integrity.

# %%
df.fillna(0, inplace=True)

# %%
print("Categorical Columns:", categorical_cols.tolist())
print("Numerical Columns:", numerical_cols.tolist())
# Out:
# Categorical Columns: ['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']
# Numerical Columns: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn_binary']

# %%
sns.barplot(
    data=df,
    x="Contract",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Contract Type")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers on a Month-to-Month contract are over ~14x more likely to churn than those in a Two year contract. This shows the contract length is one of the strongest predictors of churn and should be a key feature in the predictive model.

# %%
sns.barplot(
    data=df,
    x="InternetService",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Internet Service Type")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers with Fiber Optic internet have substantially higher churn rate (~42%) compared to DSL (~19%) and customers without InternetService (~7%). This suggests that higher cost or more complex internet services are associated with increased churn risk, possibly due to higher expectations or greater market competition

# %%
sns.barplot(
    data=df,
    x="OnlineSecurity",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Online Security Type")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers without Online Security have a substantially higher churn rate (~42%) compared to customers with Online Security (~15%) and those without Internet service (~8%). This suggests that security-related add-on services play an important role in customer retention, likely by increasing perceived value and reducing dissatisfaction related to service reliability or safety.

# %%
sns.barplot(
    data=df,
    x="TechSupport",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Tech Support Type")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers without Tech Support exhibit a significantly higher churn rate (~42%) compared to customers who receive Tech Support (~15%) and those without Internet service (~7%). This indicates that access to post-purchase technical assistance is strongly associated with reduced churn, highlighting the importance of customer support in maintaining long-term subscriptions.

# %%
sns.barplot(
    data=df,
    x="PaymentMethod",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Payment Method")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers using Electronic Check have the highest churn rate (~45%), while customers using automatic payment methods such as Bank Transfer or Credit Card show much lower churn rates (~15–17%), with Mailed Check customers falling in between. This suggests that payment convenience and automation are associated with improved retention, potentially by reducing payment friction and missed or delayed payments.

# %%
sns.barplot(
    data=df,
    x="PaperlessBilling",
    y="Churn_binary",
    estimator=lambda x: (x == 1).mean()
)

plt.title("Churn Rate by Paperless Billing Type")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# Customers enrolled in Paperless Billing have a higher churn rate (~34%) compared to customers who do not use Paperless Billing (~17%). This association may reflect underlying differences in customer segments, such as contract type or customer tenure, rather than a direct causal effect of billing method on churn.

# %% [markdown]
# # Numerical Col Checks

# %%
sns.boxplot(
    data=df,
    x="Churn",
    y="tenure"
)

plt.title("Tenure by Churn Status")
plt.show()

# %% [markdown]
# Customers who churn tend to have significantly lower tenure compared to retained customers, suggest that churning is most likely early in the customer lifestyle

# %%
sns.boxplot(
    data=df,
    x="Churn",
    y="MonthlyCharges"
)

plt.title("Monthly Charges by Churn Status")
plt.show()

# %% [markdown]
# Customers who churn tend to have higher monthly charges compared to customers who remain subscribed, as indicated by a higher median and overall distribution. This suggests that higher service costs may increase churn risk, potentially due to greater price sensitivity or unmet expectations relative to perceived value.
